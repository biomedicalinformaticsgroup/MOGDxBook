# %% [markdown]
# # MOGDx

# %%
import argparse
import pandas as pd
import numpy as np
import os
import sys  
sys.path.insert(0, './../MAIN/')
from utils import *
from GNN_MME import *
from train import *
import preprocess_functions

import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold , train_test_split
import networkx as nx
import torch
from datetime import datetime
import joblib
import warnings
import gc
warnings.filterwarnings("ignore")

print("Finished Library Import \n")
# Out:
# Finished Library Import

# %%
data_input = './../../../../data/raw'
snf_net = 'RPPA_mRNA_graph.graphml'
index_col = 'index'
target = 'paper_BRCA_Subtype_PAM50'

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')# Get GPU device name, else use CPU
print("Using %s device" % device)
get_gpu_memory()

datModalities , meta = data_parsing(data_input , ['RPPA', 'mRNA'] , target , index_col)

graph_file = data_input + '/../Networks/' + snf_net
g = nx.read_graphml(graph_file)

meta = meta.loc[sorted(meta.index)]
label = F.one_hot(torch.Tensor(list(meta.astype('category').cat.codes)).to(torch.int64))

skf = StratifiedKFold(n_splits=5 , shuffle=True) 

print(skf)

MME_input_shapes = [ datModalities[mod].shape[1] for mod in datModalities]

h = reduce(merge_dfs , list(datModalities.values()))
h = h.loc[sorted(h.index)]

g = dgl.from_networkx(g , node_attrs=['idx' , 'label'])

g.ndata['feat'] = torch.Tensor(h.to_numpy())

g.ndata['label'] = label

del datModalities
gc.collect()

output_metrics = []
test_logits = []
test_labels = []
for i, (train_index, test_index) in enumerate(skf.split(meta.index, meta)) :

    model = GCN_MME(MME_input_shapes , [16 , 16] , 64 , [32], len(meta.unique())).to(device)
    
    print(model)
    print(g)

    g = g.to(device)

    loss_plot = train(g, train_index, device ,  model , label , 2000 , 1e-3 , 100)
    plt.title(f'Loss for split {i}')
    plt.show()
    plt.clf()
    
    sampler = NeighborSampler(
        [15 for i in range(len(model.gnnlayers))],  # fanout for each layer
        prefetch_node_feats=['feat'],
        prefetch_labels=['label'],
    )
    test_dataloader = DataLoader(
        g,
        torch.Tensor(test_index).to(torch.int64).to(device),
        sampler,
        device=device,
        batch_size=1024,
        shuffle=True,
        drop_last=False,
        num_workers=0,
        use_uva=False,
    )
    
    test_output_metrics = evaluate(model , g, test_dataloader)

    print(
        "Fold : {:01d} | Test Accuracy = {:.4f} | F1 = {:.4f} ".format(
        i+1 , test_output_metrics[1] , test_output_metrics[2] )
    )
    
    test_logits.extend(test_output_metrics[-2])
    test_labels.extend(test_output_metrics[-1])
    
    output_metrics.append(test_output_metrics)
    if i == 0 : 
        best_model = model
        best_idx = i
    elif output_metrics[best_idx][1] < test_output_metrics[1] : 
        best_model = model
        best_idx   = i

    get_gpu_memory()
    del model
    gc.collect()
    torch.cuda.empty_cache()
    print('Clearing gpu memory')
    get_gpu_memory()

test_logits = torch.stack(test_logits)
test_labels = torch.stack(test_labels)
    
accuracy = []
F1 = []
i = 0
for metric in output_metrics :
    
    accuracy.append(metric[1])
    F1.append(metric[2])


print("%i Fold Cross Validation Accuracy = %2.2f \u00B1 %2.2f" %(5 , np.mean(accuracy)*100 , np.std(accuracy)*100))
print("%i Fold Cross Validation F1 = %2.2f \u00B1 %2.2f" %(5 , np.mean(F1)*100 , np.std(F1)*100))

confusion_matrix(test_logits , test_labels , meta.astype('category').cat.categories)
plt.title('Test Accuracy = %2.1f %%' % (np.mean(accuracy)*100))

precision_recall_plot , all_predictions_conf = AUROC(test_logits, test_labels , meta)

node_predictions = []
node_true        = []
display_label = meta.astype('category').cat.categories
for pred , true in zip(all_predictions_conf.argmax(1) , list(test_labels.detach().cpu().argmax(1).numpy()))  : 
    node_predictions.append(display_label[pred])
    node_true.append(display_label[true])

tst = pd.DataFrame({'Actual' : node_true , 'Predicted' : node_predictions})
# Out:
# Using cuda device
# Total = 6.4Gb 	 Reserved = 0.0Gb 	 Allocated = 0.0Gb
# StratifiedKFold(n_splits=5, random_state=None, shuffle=True)
# GCN_MME(
#   (encoder_dims): ModuleList(
#     (0): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=464, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#     (1): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=29995, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (gnnlayers): ModuleList(
#     (0): GraphConv(in=64, out=32, normalization=both, activation=None)
#     (1): GraphConv(in=32, out=5, normalization=both, activation=None)
#   )
#   (batch_norms): ModuleList(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (drop): Dropout(p=0.5, inplace=False)
# )
# Graph(num_nodes=1076, num_edges=18312,
#       ndata_schemes={'idx': Scheme(shape=(), dtype=torch.int64), 'label': Scheme(shape=(5,), dtype=torch.int64), 'feat': Scheme(shape=(30459,), dtype=torch.float32)}
#       edata_schemes={})
# Epoch 00000 | Loss 2.1236 | Train Acc. 0.1198 |
# Epoch 00005 | Loss 0.5793 | Train Acc. 0.8221 |
# Epoch 00010 | Loss 0.5015 | Train Acc. 0.8209 |
# Epoch 00015 | Loss 0.4529 | Train Acc. 0.8453 |
# Epoch 00020 | Loss 0.4528 | Train Acc. 0.8407 |
# Epoch 00025 | Loss 0.4386 | Train Acc. 0.8477 |
# Epoch 00030 | Loss 0.4149 | Train Acc. 0.8384 |
# Epoch 00035 | Loss 0.3918 | Train Acc. 0.8593 |
# Epoch 00040 | Loss 0.4049 | Train Acc. 0.8465 |
# Epoch 00045 | Loss 0.3684 | Train Acc. 0.8628 |
# Epoch 00050 | Loss 0.3694 | Train Acc. 0.8605 |
# Epoch 00055 | Loss 0.3600 | Train Acc. 0.8605 |
# Epoch 00060 | Loss 0.3668 | Train Acc. 0.8593 |
# Epoch 00065 | Loss 0.3569 | Train Acc. 0.8674 |
# Epoch 00070 | Loss 0.3505 | Train Acc. 0.8593 |
# Epoch 00075 | Loss 0.3538 | Train Acc. 0.8663 |
# Epoch 00080 | Loss 0.3626 | Train Acc. 0.8663 |
# Epoch 00085 | Loss 0.3496 | Train Acc. 0.8698 |
# Epoch 00090 | Loss 0.3443 | Train Acc. 0.8698 |
# Epoch 00095 | Loss 0.3407 | Train Acc. 0.8686 |
# Epoch 00100 | Loss 0.3445 | Train Acc. 0.8640 |
# Epoch 00105 | Loss 0.3245 | Train Acc. 0.8791 |
# Epoch 00110 | Loss 0.3360 | Train Acc. 0.8628 |
# Epoch 00115 | Loss 0.3357 | Train Acc. 0.8698 |
# Epoch 00120 | Loss 0.3274 | Train Acc. 0.8640 |
# Epoch 00125 | Loss 0.3453 | Train Acc. 0.8674 |
# Epoch 00130 | Loss 0.3425 | Train Acc. 0.8640 |
# Epoch 00135 | Loss 0.3320 | Train Acc. 0.8663 |
# Epoch 00140 | Loss 0.3244 | Train Acc. 0.8802 |
# Epoch 00145 | Loss 0.3320 | Train Acc. 0.8698 |
# Epoch 00150 | Loss 0.3366 | Train Acc. 0.8663 |
# Epoch 00155 | Loss 0.3226 | Train Acc. 0.8779 |
# Epoch 00160 | Loss 0.3238 | Train Acc. 0.8779 |
# Epoch 00165 | Loss 0.3302 | Train Acc. 0.8628 |
# Epoch 00170 | Loss 0.3291 | Train Acc. 0.8756 |
# Epoch 00175 | Loss 0.3062 | Train Acc. 0.8826 |
# Epoch 00180 | Loss 0.3263 | Train Acc. 0.8674 |
# Epoch 00185 | Loss 0.3230 | Train Acc. 0.8733 |
# Epoch 00190 | Loss 0.3194 | Train Acc. 0.8767 |
# Epoch 00195 | Loss 0.3145 | Train Acc. 0.8663 |
# Epoch 00200 | Loss 0.3128 | Train Acc. 0.8744 |
# Epoch 00205 | Loss 0.3152 | Train Acc. 0.8837 |
# Epoch 00210 | Loss 0.3273 | Train Acc. 0.8744 |
# Epoch 00215 | Loss 0.3318 | Train Acc. 0.8558 |
# Epoch 00220 | Loss 0.3043 | Train Acc. 0.8733 |
# Epoch 00225 | Loss 0.3128 | Train Acc. 0.8698 |
# Epoch 00230 | Loss 0.3152 | Train Acc. 0.8674 |
# Epoch 00235 | Loss 0.3055 | Train Acc. 0.8709 |
# Epoch 00240 | Loss 0.3094 | Train Acc. 0.8733 |
# Epoch 00245 | Loss 0.3024 | Train Acc. 0.8802 |
# Epoch 00250 | Loss 0.3134 | Train Acc. 0.8814 |
# Epoch 00255 | Loss 0.3165 | Train Acc. 0.8744 |
# Epoch 00260 | Loss 0.3073 | Train Acc. 0.8814 |
# Epoch 00265 | Loss 0.3152 | Train Acc. 0.8721 |
# Epoch 00270 | Loss 0.3091 | Train Acc. 0.8837 |
# Epoch 00275 | Loss 0.3130 | Train Acc. 0.8709 |
# Epoch 00280 | Loss 0.3136 | Train Acc. 0.8767 |
# Epoch 00285 | Loss 0.3143 | Train Acc. 0.8860 |
# Epoch 00290 | Loss 0.3145 | Train Acc. 0.8721 |
# Epoch 00295 | Loss 0.3099 | Train Acc. 0.8721 |
# Epoch 00300 | Loss 0.3114 | Train Acc. 0.8733 |
# Epoch 00305 | Loss 0.3095 | Train Acc. 0.8733 |
# Epoch 00310 | Loss 0.3081 | Train Acc. 0.8814 |
# Epoch 00315 | Loss 0.3187 | Train Acc. 0.8674 |
# Epoch 00320 | Loss 0.2970 | Train Acc. 0.8814 |
# Epoch 00325 | Loss 0.3087 | Train Acc. 0.8814 |
# Epoch 00330 | Loss 0.3209 | Train Acc. 0.8744 |
# Epoch 00335 | Loss 0.3095 | Train Acc. 0.8791 |
# Epoch 00340 | Loss 0.3131 | Train Acc. 0.8837 |
# Epoch 00345 | Loss 0.3164 | Train Acc. 0.8570 |
# Epoch 00350 | Loss 0.3074 | Train Acc. 0.8826 |
# Epoch 00355 | Loss 0.2936 | Train Acc. 0.8814 |
# Epoch 00360 | Loss 0.3128 | Train Acc. 0.8733 |
# Epoch 00365 | Loss 0.3173 | Train Acc. 0.8605 |
# Epoch 00370 | Loss 0.3197 | Train Acc. 0.8698 |
# Epoch 00375 | Loss 0.3092 | Train Acc. 0.8663 |
# Epoch 00380 | Loss 0.3080 | Train Acc. 0.8686 |
# Epoch 00385 | Loss 0.3141 | Train Acc. 0.8733 |
# Epoch 00390 | Loss 0.3060 | Train Acc. 0.8733 |
# Epoch 00395 | Loss 0.3078 | Train Acc. 0.8721 |
# Epoch 00400 | Loss 0.3187 | Train Acc. 0.8721 |
# Epoch 00405 | Loss 0.3094 | Train Acc. 0.8709 |
# Epoch 00410 | Loss 0.3031 | Train Acc. 0.8756 |
# Epoch 00415 | Loss 0.3173 | Train Acc. 0.8709 |
# Epoch 00420 | Loss 0.3169 | Train Acc. 0.8721 |
# Epoch 00425 | Loss 0.3095 | Train Acc. 0.8744 |
# Epoch 00430 | Loss 0.3188 | Train Acc. 0.8721 |
# Epoch 00435 | Loss 0.3321 | Train Acc. 0.8709 |
# Epoch 00440 | Loss 0.3085 | Train Acc. 0.8791 |
# Epoch 00445 | Loss 0.2975 | Train Acc. 0.8779 |
# Epoch 00450 | Loss 0.3133 | Train Acc. 0.8802 |
# Epoch 00455 | Loss 0.3016 | Train Acc. 0.8767 |
# Early stopping! No improvement for 100 consecutive epochs.
# Fold : 1 | Test Accuracy = 0.8843 | F1 = 0.8590
# Total = 6.4Gb 	 Reserved = 0.8Gb 	 Allocated = 0.3Gb
# Clearing gpu memory
# Total = 6.4Gb 	 Reserved = 0.3Gb 	 Allocated = 0.3Gb
# GCN_MME(
#   (encoder_dims): ModuleList(
#     (0): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=464, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#     (1): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=29995, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (gnnlayers): ModuleList(
#     (0): GraphConv(in=64, out=32, normalization=both, activation=None)
#     (1): GraphConv(in=32, out=5, normalization=both, activation=None)
#   )
#   (batch_norms): ModuleList(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (drop): Dropout(p=0.5, inplace=False)
# )
# Graph(num_nodes=1076, num_edges=18312,
#       ndata_schemes={'idx': Scheme(shape=(), dtype=torch.int64), 'label': Scheme(shape=(5,), dtype=torch.int64), 'feat': Scheme(shape=(30459,), dtype=torch.float32)}
#       edata_schemes={})
# Epoch 00000 | Loss 1.9892 | Train Acc. 0.1336 |
# Epoch 00005 | Loss 0.6128 | Train Acc. 0.8142 |
# Epoch 00010 | Loss 0.5409 | Train Acc. 0.8269 |
# Epoch 00015 | Loss 0.4918 | Train Acc. 0.8386 |
# Epoch 00020 | Loss 0.4624 | Train Acc. 0.8432 |
# Epoch 00025 | Loss 0.4308 | Train Acc. 0.8490 |
# Epoch 00030 | Loss 0.4194 | Train Acc. 0.8479 |
# Epoch 00035 | Loss 0.3866 | Train Acc. 0.8618 |
# Epoch 00040 | Loss 0.3772 | Train Acc. 0.8595 |
# Epoch 00045 | Loss 0.3553 | Train Acc. 0.8711 |
# Epoch 00050 | Loss 0.3611 | Train Acc. 0.8641 |
# Epoch 00055 | Loss 0.3606 | Train Acc. 0.8560 |
# Epoch 00060 | Loss 0.3642 | Train Acc. 0.8560 |
# Epoch 00065 | Loss 0.3435 | Train Acc. 0.8630 |
# Epoch 00070 | Loss 0.3377 | Train Acc. 0.8711 |
# Epoch 00075 | Loss 0.3378 | Train Acc. 0.8699 |
# Epoch 00080 | Loss 0.3256 | Train Acc. 0.8676 |
# Epoch 00085 | Loss 0.3280 | Train Acc. 0.8757 |
# Epoch 00090 | Loss 0.3305 | Train Acc. 0.8653 |
# Epoch 00095 | Loss 0.3337 | Train Acc. 0.8780 |
# Epoch 00100 | Loss 0.3230 | Train Acc. 0.8746 |
# Epoch 00105 | Loss 0.3238 | Train Acc. 0.8676 |
# Epoch 00110 | Loss 0.3264 | Train Acc. 0.8699 |
# Epoch 00115 | Loss 0.3127 | Train Acc. 0.8804 |
# Epoch 00120 | Loss 0.3152 | Train Acc. 0.8780 |
# Epoch 00125 | Loss 0.3017 | Train Acc. 0.8850 |
# Epoch 00130 | Loss 0.3168 | Train Acc. 0.8792 |
# Epoch 00135 | Loss 0.3115 | Train Acc. 0.8688 |
# Epoch 00140 | Loss 0.3053 | Train Acc. 0.8885 |
# Epoch 00145 | Loss 0.3069 | Train Acc. 0.8827 |
# Epoch 00150 | Loss 0.2991 | Train Acc. 0.8885 |
# Epoch 00155 | Loss 0.2939 | Train Acc. 0.8885 |
# Epoch 00160 | Loss 0.2983 | Train Acc. 0.8769 |
# Epoch 00165 | Loss 0.2968 | Train Acc. 0.8862 |
# Epoch 00170 | Loss 0.3019 | Train Acc. 0.8885 |
# Epoch 00175 | Loss 0.2941 | Train Acc. 0.8815 |
# Epoch 00180 | Loss 0.3003 | Train Acc. 0.8827 |
# Epoch 00185 | Loss 0.2977 | Train Acc. 0.8839 |
# Epoch 00190 | Loss 0.2870 | Train Acc. 0.8885 |
# Epoch 00195 | Loss 0.3023 | Train Acc. 0.8873 |
# Epoch 00200 | Loss 0.3112 | Train Acc. 0.8792 |
# Epoch 00205 | Loss 0.2935 | Train Acc. 0.8908 |
# Epoch 00210 | Loss 0.2882 | Train Acc. 0.8873 |
# Epoch 00215 | Loss 0.2853 | Train Acc. 0.8862 |
# Epoch 00220 | Loss 0.2819 | Train Acc. 0.8920 |
# Epoch 00225 | Loss 0.2824 | Train Acc. 0.8920 |
# Epoch 00230 | Loss 0.2952 | Train Acc. 0.8827 |
# Epoch 00235 | Loss 0.2861 | Train Acc. 0.8943 |
# Epoch 00240 | Loss 0.2919 | Train Acc. 0.8862 |
# Epoch 00245 | Loss 0.2810 | Train Acc. 0.8827 |
# Epoch 00250 | Loss 0.2878 | Train Acc. 0.8850 |
# Epoch 00255 | Loss 0.2834 | Train Acc. 0.8897 |
# Epoch 00260 | Loss 0.2880 | Train Acc. 0.8920 |
# Epoch 00265 | Loss 0.2834 | Train Acc. 0.8990 |
# Epoch 00270 | Loss 0.2843 | Train Acc. 0.8978 |
# Epoch 00275 | Loss 0.2849 | Train Acc. 0.8862 |
# Epoch 00280 | Loss 0.2781 | Train Acc. 0.8931 |
# Epoch 00285 | Loss 0.2886 | Train Acc. 0.8839 |
# Epoch 00290 | Loss 0.2915 | Train Acc. 0.8873 |
# Epoch 00295 | Loss 0.2977 | Train Acc. 0.8862 |
# Epoch 00300 | Loss 0.2795 | Train Acc. 0.8931 |
# Epoch 00305 | Loss 0.2827 | Train Acc. 0.8827 |
# Epoch 00310 | Loss 0.2880 | Train Acc. 0.8885 |
# Epoch 00315 | Loss 0.2904 | Train Acc. 0.8839 |
# Epoch 00320 | Loss 0.2761 | Train Acc. 0.8908 |
# Epoch 00325 | Loss 0.2783 | Train Acc. 0.8920 |
# Epoch 00330 | Loss 0.2813 | Train Acc. 0.8920 |
# Epoch 00335 | Loss 0.2802 | Train Acc. 0.8873 |
# Epoch 00340 | Loss 0.2915 | Train Acc. 0.8897 |
# Epoch 00345 | Loss 0.2842 | Train Acc. 0.8920 |
# Epoch 00350 | Loss 0.2846 | Train Acc. 0.8873 |
# Epoch 00355 | Loss 0.2861 | Train Acc. 0.8839 |
# Epoch 00360 | Loss 0.2843 | Train Acc. 0.8862 |
# Epoch 00365 | Loss 0.2816 | Train Acc. 0.9001 |
# Epoch 00370 | Loss 0.2943 | Train Acc. 0.8920 |
# Epoch 00375 | Loss 0.2844 | Train Acc. 0.8873 |
# Epoch 00380 | Loss 0.2813 | Train Acc. 0.8966 |
# Epoch 00385 | Loss 0.2745 | Train Acc. 0.8931 |
# Epoch 00390 | Loss 0.2740 | Train Acc. 0.8885 |
# Epoch 00395 | Loss 0.2938 | Train Acc. 0.8815 |
# Epoch 00400 | Loss 0.2801 | Train Acc. 0.8897 |
# Epoch 00405 | Loss 0.2768 | Train Acc. 0.8873 |
# Epoch 00410 | Loss 0.2776 | Train Acc. 0.8873 |
# Early stopping! No improvement for 100 consecutive epochs.
# Fold : 2 | Test Accuracy = 0.8465 | F1 = 0.8106
# Total = 6.4Gb 	 Reserved = 0.9Gb 	 Allocated = 0.4Gb
# Clearing gpu memory
# Total = 6.4Gb 	 Reserved = 0.3Gb 	 Allocated = 0.3Gb
# GCN_MME(
#   (encoder_dims): ModuleList(
#     (0): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=464, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#     (1): Encoder(
#       (encoder): ModuleList(
#         (0): Linear(in_features=29995, out_features=500, bias=True)
#         (1): Linear(in_features=500, out_features=16, bias=True)
#       )
#       (norm): ModuleList(
#         (0): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (decoder): Sequential(
#         (0): Linear(in_features=16, out_features=64, bias=True)
#       )
#       (drop): Dropout(p=0.5, inplace=False)
#     )
#   )
#   (gnnlayers): ModuleList(
#     (0): GraphConv(in=64, out=32, normalization=both, activation=None)
#     (1): GraphConv(in=32, out=5, normalization=both, activation=None)
#   )
#   (batch_norms): ModuleList(
#     (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (drop): Dropout(p=0.5, inplace=False)
# )
# Graph(num_nodes=1076, num_edges=18312,
#       ndata_schemes={'idx': Scheme(shape=(), dtype=torch.int64), 'label': Scheme(shape=(5,), dtype=torch.int64), 'feat': Scheme(shape=(30459,), dtype=torch.float32)}
#       edata_schemes={})
# Epoch 00000 | Loss 2.2885 | Train Acc. 0.1394 |
# Epoch 00005 | Loss 0.7027 | Train Acc. 0.7991 |
# Epoch 00010 | Loss 0.6419 | Train Acc. 0.7933 |
# Epoch 00015 | Loss 0.5853 | Train Acc. 0.8084 |
# Epoch 00020 | Loss 0.5222 | Train Acc. 0.8281 |
# Epoch 00025 | Loss 0.5050 | Train Acc. 0.8374 |
# Epoch 00030 | Loss 0.4662 | Train Acc. 0.8316 |
# Epoch 00035 | Loss 0.4393 | Train Acc. 0.8444 |
# Epoch 00040 | Loss 0.4536 | Train Acc. 0.8525 |
# Epoch 00045 | Loss 0.4194 | Train Acc. 0.8490 |
# Epoch 00050 | Loss 0.4150 | Train Acc. 0.8490 |
# Epoch 00055 | Loss 0.3948 | Train Acc. 0.8560 |
# Epoch 00060 | Loss 0.3932 | Train Acc. 0.8606 |
# Epoch 00065 | Loss 0.4023 | Train Acc. 0.8560 |
# Epoch 00070 | Loss 0.4016 | Train Acc. 0.8513 |
# Epoch 00075 | Loss 0.3944 | Train Acc. 0.8467 |
# Epoch 00080 | Loss 0.3816 | Train Acc. 0.8548 |
# Epoch 00085 | Loss 0.3753 | Train Acc. 0.8548 |
# Epoch 00090 | Loss 0.3611 | Train Acc. 0.8676 |
# Epoch 00095 | Loss 0.3773 | Train Acc. 0.8571 |
# Epoch 00100 | Loss 0.3624 | Train Acc. 0.8537 |
# Epoch 00105 | Loss 0.3546 | Train Acc. 0.8606 |
# Epoch 00110 | Loss 0.3553 | Train Acc. 0.8699 |
# Epoch 00115 | Loss 0.3611 | Train Acc. 0.8734 |
# Epoch 00120 | Loss 0.3542 | Train Acc. 0.8618 |
# Epoch 00125 | Loss 0.3467 | Train Acc. 0.8618 |
# Epoch 00130 | Loss 0.3538 | Train Acc. 0.8618 |
# Epoch 00135 | Loss 0.3655 | Train Acc. 0.8734 |
# Epoch 00140 | Loss 0.3296 | Train Acc. 0.8711 |
# Epoch 00145 | Loss 0.3405 | Train Acc. 0.8769 |
# Epoch 00150 | Loss 0.3388 | Train Acc. 0.8664 |
# Epoch 00155 | Loss 0.3454 | Train Acc. 0.8537 |
# Epoch 00160 | Loss 0.3403 | Train Acc. 0.8653 |
# Epoch 00165 | Loss 0.3586 | Train Acc. 0.8641 |
# Epoch 00170 | Loss 0.3346 | Train Acc. 0.8734 |
# Epoch 00175 | Loss 0.3406 | Train Acc. 0.8688 |
# Epoch 00180 | Loss 0.3341 | Train Acc. 0.8653 |
# Epoch 00185 | Loss 0.3447 | Train Acc. 0.8711 |
# Epoch 00190 | Loss 0.3348 | Train Acc. 0.8769 |
# Epoch 00195 | Loss 0.3369 | Train Acc. 0.8699 |
# Epoch 00200 | Loss 0.3261 | Train Acc. 0.8722 |
# Epoch 00205 | Loss 0.3327 | Train Acc. 0.8722 |
# Epoch 00210 | Loss 0.3314 | Train Acc. 0.8676 |
# Epoch 00215 | Loss 0.3270 | Train Acc. 0.8676 |
# Epoch 00220 | Loss 0.3341 | Train Acc. 0.8676 |
# Epoch 00225 | Loss 0.3273 | Train Acc. 0.8746 |
# Epoch 00230 | Loss 0.3303 | Train Acc. 0.8688 |
# Epoch 00235 | Loss 0.3378 | Train Acc. 0.8746 |
# Epoch 00240 | Loss 0.3280 | Train Acc. 0.8780 |
# Epoch 00245 | Loss 0.3357 | Train Acc. 0.8746 |
# Epoch 00250 | Loss 0.3295 | Train Acc. 0.8734 |
# Epoch 00255 | Loss 0.3409 | Train Acc. 0.8664 |
# Epoch 00260 | Loss 0.3304 | Train Acc. 0.8780 |
# Epoch 00265 | Loss 0.3311 | Train Acc. 0.8722 |
# Epoch 00270 | Loss 0.3340 | Train Acc. 0.8746 |
# Epoch 00275 | Loss 0.3301 | Train Acc. 0.8734 |
# Epoch 00280 | Loss 0.3262 | Train Acc. 0.8734 |
# Epoch 00285 | Loss 0.3304 | Train Acc. 0.8722 |
# Epoch 00290 | Loss 0.3313 | Train Acc. 0.8722 |
# Epoch 00295 | Loss 0.3262 | Train Acc. 0.8688 |
# Epoch 00300 | Loss 0.3175 | Train Acc. 0.8769 |
# Epoch 00305 | Loss 0.3277 | Train Acc. 0.8722 |
# Epoch 00310 | Loss 0.3334 | Train Acc. 0.8757 |
# Epoch 00315 | Loss 0.3260 | Train Acc. 0.8711 |
# Epoch 00320 | Loss 0.3303 | Train Acc. 0.8734 |
# Epoch 00325 | Loss 0.3255 | Train Acc. 0.8722 |
# Epoch 00330 | Loss 0.3256 | Train Acc. 0.8746 |
# Epoch 00335 | Loss 0.3148 | Train Acc. 0.8769 |
# Epoch 00340 | Loss 0.3266 | Train Acc. 0.8711 |
# Epoch 00345 | Loss 0.3287 | Train Acc. 0.8688 |
# Epoch 00350 | Loss 0.3232 | Train Acc. 0.8711 |

# %%
# test the model
print("Testing...")
acc = layerwise_infer(
    device, g, np.arange(len(g.nodes())), best_model, batch_size=4096
)
print("Test Accuracy {:.4f}".format(acc.item()))
# Out:
# Testing...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 70.94it/s]
# Test Accuracy 0.8838

# %%
best_model.eval()
with torch.no_grad():
    emb = best_model.embedding_extraction(
        g, g.ndata['feat'] ,device, 4096
    )  # pred in buffer_device

tsne_embedding_plot(emb.detach().cpu().numpy() , meta)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 78.27it/s]
